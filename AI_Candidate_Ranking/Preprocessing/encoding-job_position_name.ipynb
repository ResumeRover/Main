# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('resume_data.csv')

# %% [markdown]
# rename the column because there is an unwanted character in the column name.

# %%
df.rename(columns={'﻿job_position_name': 'job_position_name'}, inplace=True)

# %%
df['job_position_name'].unique()
# Out:
# array(['Senior Software Engineer', 'Machine Learning (ML) Engineer',
#        'Executive/ Senior Executive- Trade Marketing, Hygiene Products',
#        'Business Development Executive', 'Senior iOS Engineer',
#        'AI Engineer', 'Mechanical Engineer', 'Mechanical Designer',
#        'Asst. Manager/ Manger (Administrative)',
#        'Database Administrator (DBA)',
#        'System Administrator (Operation & Maintenance of Server, Storage & Service Desk System)',
#        'Project Coordinator (Civil)', 'Executive/ Sr. Executive -IT',
#        'Network Support Engineer',
#        'Intern (Generative AI Engineering - 2D/3D Image Generation)',
#        'Executive - VAT', 'Sr.Officer / Executive - Internal Audit',
#        'Management Trainee - Mechanical', 'HR Officer', 'DevOps Engineer',
#        'Data Engineer',
#        'Head of Internal Control & Compliance (ICC) - SEVP/DMD',
#        'Full Stack Developer (Python,React js)', 'Civil Engineer',
#        'Data Science Engineer',
# ...

# %% [markdown]
# encoding job_position_name column using the MiniLM sentence transformer(BERT variant)

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import pandas as pd

# Load the model once globally
model = SentenceTransformer('all-MiniLM-L6-v2')

# Text normalization: strip spaces, lowercase everything
def normalize_text(text):
    return text.strip().lower()

# Main function to encode job titles
def encode_job_titles(df, column_name='job_position_name', output_column='job_position_embedding'):
    """
    Encode normalized job titles into dense vectors and store in a new column.

    Args:
        df (pd.DataFrame): DataFrame with job titles
        column_name (str): Name of the column to encode
        output_column (str): Name of the column to store embeddings

    Returns:
        pd.DataFrame: Modified DataFrame with added embedding column
    """
    job_titles = df[column_name].fillna("").astype(str).apply(normalize_text).tolist()
    embeddings = model.encode(job_titles, show_progress_bar=True)
    
    # Store embeddings as a list in the new column
    df[output_column] = list(embeddings)  # Convert numpy array to list to store it in DataFrame
    
    return df

# Encode the job titles
df = encode_job_titles(df)
# Out:
# Batches:   0%|          | 0/299 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#   address                                   career_objective  \
# 0     NaN  Big data analytics working and database wareho...
# 1     NaN  Fresher looking to join as a data analyst and ...
# 2     NaN                                                NaN
# 3     NaN  To obtain a position in a fast-paced business ...
# 4     NaN  Professional accountant with an outstanding wo...
#
#                                               skills  \
# 0  ['Big Data', 'Hadoop', 'Hive', 'Python', 'Mapr...
# 1  ['Data Analysis', 'Data Analytics', 'Business ...
# 2  ['Software Development', 'Machine Learning', '...
# 3  ['accounts payables', 'accounts receivables', ...
# 4  ['Analytical reasoning', 'Compliance testing k...
#
#                         educational_institution_name  \
# 0  ['The Amity School of Engineering & Technology...
# 1  ['Delhi University - Hansraj College', 'Delhi ...
# 2    ['Birla Institute of Technology (BIT), Ranchi']
# 3  ['Martinez Adult Education, Business Training ...
# ...
